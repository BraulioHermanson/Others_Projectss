# %%
#importando as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %% [markdown]
# ### Tesouro
# - link: https://www.tesourotransparente.gov.br/ckan/dataset/taxas-dos-titulos-ofertados-pelo-tesouro-direto/resource/796d2059-14e9-44e3-80c9-2d9e30b405c1

# %%
link_te = 'https://www.tesourotransparente.gov.br/ckan/dataset/df56aa42-484a-4a59-8184-7676580c81e3/resource/796d2059-14e9-44e3-80c9-2d9e30b405c1/download/PrecoTaxaTesouroDireto.csv'
tesouro = pd.read_csv(link_te, sep=';', decimal=',')
tesouro['Data Base'] = pd.to_datetime(tesouro['Data Base'], format='%d/%m/%Y')
tesouro = tesouro.loc[tesouro['Tipo Titulo']=='Tesouro Selic', :]
display(tesouro)
# Out:
#           Tipo Titulo Data Vencimento  Data Base  Taxa Compra Manha  \
# 20      Tesouro Selic      16/02/2005 2005-02-04               0.01
# 21      Tesouro Selic      18/01/2006 2005-02-04               0.12
# 22      Tesouro Selic      17/01/2007 2005-02-04               0.18
# 23      Tesouro Selic      18/06/2008 2005-02-04               0.28
# 24      Tesouro Selic      18/03/2009 2005-02-04               0.31
# ...               ...             ...        ...                ...
# 124401  Tesouro Selic      07/03/2012 2011-09-08               0.00
# 124402  Tesouro Selic      07/03/2013 2011-09-08               0.00
# 124403  Tesouro Selic      07/03/2014 2011-09-08               0.00
# 124404  Tesouro Selic      07/03/2015 2011-09-08               0.00
# 124405  Tesouro Selic      07/03/2017 2011-09-08               0.00
#
#         Taxa Venda Manha  PU Compra Manha  PU Venda Manha  PU Base Manha
# 20                  0.03          2198.56         2198.56        2197.09
# ...

# %% [markdown]
# ### Selic
# - link: https://dados.gov.br/dataset/11-taxa-de-juros-selic

# %%
link_se ='https://api.bcb.gov.br/dados/serie/bcdata.sgs.4390/dados?formato=csv'
selic = pd.read_csv(link_se, sep=';', decimal=',')
selic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   data    435 non-null    object
#  1   valor   435 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 6.9+ KB

# %%
selic['data'] = pd.to_datetime(selic['data'], format='%d/%m/%Y')
display(selic)
# Out:
#           data  valor
# 0   1986-06-01   1.27
# 1   1986-07-01   1.95
# 2   1986-08-01   2.57
# 3   1986-09-01   2.94
# 4   1986-10-01   1.96
# ..         ...    ...
# 430 2022-04-01   0.83
# 431 2022-05-01   1.03
# 432 2022-06-01   1.02
# 433 2022-07-01   1.03
# 434 2022-08-01   1.02
#
# [435 rows x 2 columns]

# %% [markdown]
# ### IPCA

# %%
#new option
url ='https://servicodados.ibge.gov.br/api/v3/agregados/118/periodos/199801|199802|199803|199804|199805|199806|199807|199808|199809|199810|199811|199812|199901|199902|199903|199904|199905|199906|199907|199908|199909|199910|199911|199912|200001|200002|200003|200004|200005|200006|200007|200008|200009|200010|200011|200012|200101|200102|200103|200104|200105|200106|200107|200108|200109|200110|200111|200112|200201|200202|200203|200204|200205|200206|200207|200208|200209|200210|200211|200212|200301|200302|200303|200304|200305|200306|200307|200308|200309|200310|200311|200312|200401|200402|200403|200404|200405|200406|200407|200408|200409|200410|200411|200412|200501|200502|200503|200504|200505|200506|200507|200508|200509|200510|200511|200512|200601|200602|200603|200604|200605|200606|200607|200608|200609|200610|200611|200612|200701|200702|200703|200704|200705|200706|200707|200708|200709|200710|200711|200712|200801|200802|200803|200804|200805|200806|200807|200808|200809|200810|200811|200812|200901|200902|200903|200904|200905|200906|200907|200908|200909|200910|200911|200912|201001|201002|201003|201004|201005|201006|201007|201008|201009|201010|201011|201012|201101|201102|201103|201104|201105|201106|201107|201108|201109|201110|201111|201112|201201|201202|201203|201204|201205|201206|201207|201208|201209|201210|201211|201212|201301|201302|201303|201304|201305|201306|201307|201308|201309|201310|201311|201312|201401|201402|201403|201404|201405|201406|201407|201408|201409|201410|201411|201412|201501|201502|201503|201504|201505|201506|201507|201508|201509|201510|201511|201512|201601|201602|201603|201604|201605|201606|201607|201608|201609|201610|201611|201612|201701|201702|201703|201704|201705|201706|201707|201708|201709|201710|201711|201712|201801|201802|201803|201804|201805|201806|201807|201808|201809|201810|201811|201812|201901|201902|201903|201904|201905|201906|201907|201908|201909|201910|201911|201912|202001|202002|202003|202004|202005|202006|202007|202008|202009|202010|202011|202012|202101|202102|202103|202104|202105|202106|202107|202108|202109|202110|202111|202112|202201|202202|202203|202204|202205|202206|202207/variaveis/306?localidades=N1[all]'
dados = requests.get(url).json()
titulo = dados[0]['variavel']
valores = dados[0]['resultados'][0]['series'][0]['serie']
#print(dados)
#print(titulo)
print(valores)
# Out:
# {'199801': '0.59', '199802': '0.44', '199803': '0.28', '199804': '0.17', '199805': '0.48', '199806': '0.04', '199807': '-0.04', '199808': '-0.38', '199809': '-0.16', '199810': '0.05', '199811': '-0.10', '199812': '0.33', '199901': '0.58', '199902': '1.03', '199903': '1.05', '199904': '0.51', '199905': '0.30', '199906': '0.22', '199907': '1.18', '199908': '0.65', '199909': '0.36', '199910': '1.21', '199911': '0.96', '199912': '0.58', '200001': '0.53', '200002': '0.11', '200003': '0.19', '200004': '0.40', '200005': '0.06', '200006': '0.31', '200007': '1.68', '200008': '1.36', '200009': '0.28', '200010': '0.16', '200011': '0.33', '200012': '0.56', '200101': '0.48', '200102': '0.43', '200103': '0.35', '200104': '0.56', '200105': '0.44', '200106': '0.59', '200107': '1.39', '200108': '0.74', '200109': '0.29', '200110': '0.82', '200111': '0.70', '200112': '0.65', '200201': '0.45', '200202': '0.35', '200203': '0.60', '200204': '0.76', '200205': '0.25', '200206': '0.47', '200207': '1.24', '20
# ...

# %%
dff = pd.DataFrame(valores,index=[0])

# %%
dff
# Out:
#   199801 199802 199803 199804 199805 199806 199807 199808 199809 199810  ...  \
# 0   0.59   0.44   0.28   0.17   0.48   0.04  -0.04  -0.38  -0.16   0.05  ...
#
#   202110 202111 202112 202201 202202 202203 202204 202205 202206 202207
# 0   1.22   0.87   0.64   0.47   1.02   1.54   1.03   0.52   0.73  -0.61
#
# [1 rows x 295 columns]

# %%
dff.T
# Out:
#             0
# 199801   0.59
# 199802   0.44
# 199803   0.28
# 199804   0.17
# 199805   0.48
# ...       ...
# 202203   1.54
# 202204   1.03
# 202205   0.52
# 202206   0.73
# 202207  -0.61
#
# [295 rows x 1 columns]
